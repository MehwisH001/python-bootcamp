# %% [markdown]
# ## OPERATORS

# %% [markdown]
# Arithmetic Operators
# - Q1. Write a Python program to perform addition, subtraction, multiplication, division, floor division, and modulus of two numbers.
# - Q2. Write a program to calculate the power of a number using the exponent operator.
# - Q3. Write a program to find the average of three numbers.
#
# Comparison Operators
# - Q4. Write a program to compare two numbers and print which one is greater, smaller, or equal.
# - Q5. Write a program to check whether a number is positive, negative, or zero.
#
# Logical Operators
# - Q6. Write a program to check whether a number lies between 10 and 50 using logical operators.
# - Q7. Write a program to check whether a person is eligible to vote (use and operator).
#
# Assignment Operators
# - Q8. Write a program to demonstrate all assignment operators (=, +=, -=, *=, /=).
#
# Bitwise Operators
# - Q9. Write a program to perform bitwise AND, OR, and XOR on two numbers.
#
# Membership Operators
# - Q10. Write a program to check whether a value exists in a list using membership operators.

# %% [markdown]
# ## VARIABLES & DATATYPES

# %% [markdown]
# - Write a Python program to declare variables of type int, float, string, and boolean and print their values along with their data types.
#
# - Write a program to take user input for name, age, and marks, then display them in a proper format.
#
# - Write a Python program to swap two numbers using:
# (a) a third variable
# (b) without using a third variable
#
# - Write a program to convert:
# integer to float,
# float to integer
# string to integer
#
# - Write a Python program to calculate the sum, difference, product, and division of two numbers.
#
# - Write a program to check the type of a variable entered by the user.
#
# - Write a Python program to find the area of a circle using variables.
#
# - Write a program that demonstrates multiple assignment in Python.
#
# - Write a Python program to store marks of five subjects and calculate the average.
#
# - Write a program to show the difference between mutable and immutable data types using examples.

# %% [markdown]
# ## Syntax and Semantics

# %% [markdown]
# - Write a Python program to print “Hello, Python!”.
#
# - Identify and correct the syntax error:
# print("Welcome to Python)
#
# - Write a program to take two numbers and print their sum.
#
# - Find the syntax error:
# if x = 10:
#     print(x)
#
# - What is the output of the following code? Explain why.
# x = 5
# x = x + 2
# print(x)
#
#
# - Find the logical (semantic) error:
# length = 10
# breadth = 5
# area = length + breadth
# print(area)
#
# - Write a program to calculate the area of a rectangle (use correct logic).
#
# - Why does this code NOT give error, but gives wrong result?
# age = "25"
# print(age + 5)
